# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Machine Learning
# </b></font> </br></p>
# <p><font size="5" color='grey'> <b>
# Large Language Model - einfacher Chatbot
# </b></font> </br></p>
#
# ---

# %% [markdown]
# # **0  <font color='orange'>|</font> Install & Import**
# ***

# %%
# !pip -q install gradio
# !pip -q install -U langchain_community langchain langgraph langchain-groq duckduckgo-search

# %%
import os
from google.colab import userdata

from langchain.schema import HumanMessage, AIMessage, SystemMessage
from langchain.chains import LLMChain
import langchain.schema as me
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

import gradio as gr

# %% [markdown]
# # **1 <font color='orange'>|</font> Understand**
# ***

# %% [markdown]
# Erstellen Sie einen ChatBots unter Verwendung von LangChain, LLM Groq und Gradio als User-Interface.

# %% [markdown]
# # **2 <font color='orange'>|</font>  Prepare**
#
# ---

# %%
# Groq API Schlüssel setzen
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# %% [markdown]
# # **3 <font color='orange'>|</font>  Modeling**
# ---

# %% [markdown]
# # **4 <font color='orange'>|</font> Evaluate**
# ---

# %% [markdown]
# # **5 <font color='orange'>|</font> Deploy (Apply)**
# ---
