# %%
import chromadb
from chromadb.config import Settings

# Erstellen Sie eine Verbindung zur Chroma-Datenbank
client_settings = Settings(persist_directory=r"C:/Users/ralfb/OneDrive/Desktop/Kurse/VectorStore")

client2 = chromadb.Client(client_settings)

# Listen Sie alle Collections in der Datenbank auf
collections = client2.list_collections()

# Drucken Sie die Namen der Collections
print("Verfügbare Collections in der Chroma-Datenbank:")
for collection in collections:
    print(collection.name)
# Out:
# Verfügbare Collections in der Chroma-Datenbank:
