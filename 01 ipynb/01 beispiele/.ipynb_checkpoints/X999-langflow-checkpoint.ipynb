# %%
from langflow.load import run_flow_from_json
TWEAKS = {
  "Prompt-TeoZe": {},
  "ChatOutput-h6VwY": {},
  "ChatInput-0CRQH": {},
  "OllamaModel-QiVLQ": {}
}

result = run_flow_from_json(flow=r"C:\Users\ralfb\OneDrive\Desktop\Kurse\MachineLearning\01 ipynb\01 beispiele\Basic prompting w ollama.json",
                            input_value="Hello, who you are?",
                            tweaks=TWEAKS)

# %%
result
# Out:
# [RunOutputs(inputs={'input_value': 'Hello, who you are?'}, outputs=[ResultData(results="Hello! I'm an AI digital assistant with a focus on coding and programming expertise. My purpose is to provide guidance, answer your questions related to various coding languages, algorithms, development practices, and more. How can I assist you today in the realm of computer science or technology?", artifacts={'message': "Hello! I'm an AI digital assistant with a focus on coding and programming expertise. My purpose is to provide guidance, answer your questions related to various coding languages, algorithms, development practices, and more. How can I assist you today in the realm of computer science or technology?", 'sender': 'Machine', 'sender_name': 'AI'}, messages=[ChatOutputResponse(message="Hello! I'm an AI digital assistant with a focus on coding and programming expertise. My purpose is to provide guidance, answer your questions related to various coding languages, algorithms, development p
# ...

# %%
result = run_flow_from_json(flow=r"C:\Users\ralfb\OneDrive\Desktop\Kurse\MachineLearning\01 ipynb\01 beispiele\Basic prompting w ollama.json",
                            input_value="What is Python?",
                            tweaks=TWEAKS)

# %%
result

# %%
len(result)
