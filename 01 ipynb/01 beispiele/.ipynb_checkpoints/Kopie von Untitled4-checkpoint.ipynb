# %%
# !pip install -q openai

# %%
from openai import OpenAI

client = OpenAI(
    base_url='http://localhost:11434/v1/',

    # required but ignored
    api_key='ollama',
)

# %%
# %%time
chat_completion = client.chat.completions.create(
    messages=[
        {
            'role': 'user',
            'content': 'Who was Albert Einstein?',
        }
    ],
    model='phi3',
)
# Out:
# CPU times: total: 0 ns
# Wall time: 5.65 s

# %%
chat_completion.dump
# Out:
# ChatCompletion(id='chatcmpl-872', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content=' Albert Einstein was a theoretical physicist born on March 14, 1879, in Ulm, Germany. He is most famously known for his development of the theory of relativity and contributions to quantum mechanics. His mass-energy equivalence formula E=mc^2 from the special theory of relativity has become one of the best-known equations in physics.\n\n\nEinstein was awarded the Nobel Prize in Physics in 1921 for his discovery of the law of the photoelectric effect, which was pivotal to quantum theory. Beyond his scientific work, he had a significant influence on philosophy and culture throughout the world, often noted as one of the most influential scientists of all time. He became a Swiss citizen in 1901 and later renounced German citizenship in 1933 due to political beliefs. Einstein passed away on April 18, 1955, in Princeton, New Jersey, USA.', role='assistant',
# ...
