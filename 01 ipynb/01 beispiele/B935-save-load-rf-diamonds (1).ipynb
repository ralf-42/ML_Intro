# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Machine Learning
# </b></font> </br></p>
# <p><font size="5" color='grey'> <b>
# Supervised Learning - Random Forest - Diamonds
# </b></font> </br></p>
#
# ---

# %% [markdown]
# ![diamond (Klein).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Bild von <a href="https://pixabay.com/de/users/colin00b-346653/?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=1186139">Colin Behrens</a> auf <a href="https://pixabay.com/de//?utm_source=link-attribution&amp;utm_medium=referral&amp;utm_campaign=image&amp;utm_content=1186139">Pixabay</a>

# %% [markdown]
# # **0  <font color='orange'>|</font> Install & Import**
# ***

# %%
# Install

# %%
# Import
import pandas as pd

from sklearn.datasets import fetch_openml
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.decomposition import PCA

import plotly.express as px
import plotly.subplots as sp

from yellowbrick.regressor import residuals_plot
from yellowbrick.regressor import prediction_error
from yellowbrick.model_selection import feature_importances

import joblib

# %%
# Warnung ausstellen
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **1  <font color='orange'>|</font> Understand**
# ***

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Aufgabe verstehen</br>
# ✅ Daten sammeln</br>
# ✅ Statistische Analyse (Min, Max, Mean, Korrelation, ...)</br>
# ✅ Datenvisualisierung (Streudiagramm, Box-Plot, ...)</br>
# ✅ Prepare Schritte festlegen</br>

# %% [markdown]
# <p><font color='black' size="5">
# Anwendungsfall
# </font></p>
#
# ---
#
# Dieser klassische Datensatz enthält die Preise und andere Attribute von fast 54.000 Diamanten.
#
#
#
# [DataSet](https://www.openml.org/search?type=data&status=active&id=42225)
#
# [Info](https://www.kaggle.com/datasets/shivam2503/diamonds)

# %%
data_id = 42225
df = fetch_openml(parser='auto', target_column='default-target', data_id=data_id)

# %%
label = 'price'
features = [n for n in df.frame.columns if n != label]

target = df.frame[label].copy()
data = df.frame[features].copy()

# %% [markdown]
# <p><font color='black' size="5">
# EDA (Exploratory Data Analysis) mit Pandas
# </font></p>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   x        53940 non-null  float64
#  7   y        53940 non-null  float64
#  8   z        53940 non-null  float64
# dtypes: category(3), float64(6)
# memory usage: 2.6 MB

# %%
data.describe().T
# Out:
#          count       mean       std   min    25%    50%    75%    max
# carat  53940.0   0.797940  0.474011   0.2   0.40   0.70   1.04   5.01
# depth  53940.0  61.749405  1.432621  43.0  61.00  61.80  62.50  79.00
# table  53940.0  57.457184  2.234491  43.0  56.00  57.00  59.00  95.00
# x      53940.0   5.731157  1.121761   0.0   4.71   5.70   6.54  10.74
# y      53940.0   5.734526  1.142135   0.0   4.72   5.71   6.54  58.90
# z      53940.0   3.538734  0.705699   0.0   2.91   3.53   4.04  31.80

# %%
data.groupby('cut').count()
# Out:
#            carat  color  clarity  depth  table      x      y      z
# cut
# Very Good  12082  12082    12082  12082  12082  12082  12082  12082
# Fair        1610   1610     1610   1610   1610   1610   1610   1610
# Good        4906   4906     4906   4906   4906   4906   4906   4906
# Ideal      21551  21551    21551  21551  21551  21551  21551  21551
# Premium    13791  13791    13791  13791  13791  13791  13791  13791

# %%
data.groupby('color').count()
# Out:
#        carat    cut  clarity  depth  table      x      y      z
# color
# D       6775   6775     6775   6775   6775   6775   6775   6775
# E       9797   9797     9797   9797   9797   9797   9797   9797
# F       9542   9542     9542   9542   9542   9542   9542   9542
# G      11292  11292    11292  11292  11292  11292  11292  11292
# H       8304   8304     8304   8304   8304   8304   8304   8304
# I       5422   5422     5422   5422   5422   5422   5422   5422
# J       2808   2808     2808   2808   2808   2808   2808   2808

# %% [markdown]
# <p><font color='black' size="5">
# EDA (Exploratory Data Analysis) mit Plotly
# </font></p>

# %%
title_ = 'Depth'
b1 = px.box(data['depth'], title=title_, width=600, height=600)

title_ = 'Carat'
b2 = px.box(data['carat'], title=title_, width=600, height=600)

title_ = 'Table'
b3 = px.box(data['table'], title=title_, width=600, height=600)

fig = sp.make_subplots(rows=1, cols=3, subplot_titles=('Depth', 'Carat', 'Table'))

for trace in b1.data:
    fig.add_trace(trace, row=1, col=1)

for trace in b2.data:
    fig.add_trace(trace, row=1, col=2)

for trace in b3.data:
    fig.add_trace(trace, row=1, col=3)

# Layout anpassen
fig.update_layout(width=1000, height=500, title_text='Box-Plots')

# Plot anzeigen
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # **2 <font color='orange'>|</font>  Prepare**
#
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Nicht benötigte Features löschen</br>
# ✅ Datentyp ermitteln/ändern</br>
# ✅ Duplikate ermitteln/löschen</br>
# ✅ Missing Values behandeln</br>
# ✅ Ausreißer behandeln</br>
# ✅ Kategorischer Features codieren</br>
# ✅ Numerischer Features skalieren</br>
# ✅ Feature-Engineering (neue Features schaffen)</br>
# ✅ Dimensionalität reduzieren</br>
# ✅ Resampling (Over-/Undersampling)</br>
# ✅ Pipeline erstellen/konfigurieren</br>
# ✅ Train-Test-Split durchführen</br>

# %% [markdown]
# <p><font color='black' size="5">
# Datentyp ermitteln
# </font></p>

# %%
all_col = data.columns
num_col = data.select_dtypes(include='number').columns
cat_col = data.select_dtypes(exclude='number').columns

# %% [markdown]
# <p><font color='black' size="5">
# Codierung
# </font></p>

# %%
cat_seq = [['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'],['J', 'I', 'H', 'G', 'F', 'E', 'D'], ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']]
data[cat_col] = OrdinalEncoder(categories=cat_seq).fit_transform(data[cat_col])

# %% [markdown]
# <p><font color='black' size="5">
# Train-Test-Set
# </font></p>

# %%
data_train, data_test, target_train, target_test = train_test_split(data, target, test_size=0.3, random_state=42)
data_train.shape, data_test.shape, target_train.shape, target_test.shape
# Out:
# ((37758, 9), (16182, 9), (37758,), (16182,))

# %% [markdown]
# # **3 <font color='orange'>|</font>  Modeling**
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Modellauswahl treffen</br>
# ✅ Pipeline erweitern/konfigurieren</br>
# ✅ Training durchführen</br>
# ✅ Hyperparameter Tuning</br>
# ✅ Cross-Valdiation</br>
# ✅ Bootstrapping</br>
# ✅ Regularization</br>

# %% [markdown]
#  <p><font color='black' size="5">
# Modellauswahl & Training
# </font></p>

# %%
model = MLPRegressor()
# Out:
# RandomForestRegressor()

# %%
model.fit(data_train, target_train)

# %% [markdown]
# # **4 <font color='orange'>|</font> Evaluate**
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Prognose (Train, Test) erstellen</br>
# ✅ Modellgüte prüfen</br>
# ✅ Residuenanalyse erstellen</br>
# ✅ Feature Importance/Selektion prüfen</br>
# ✅ Robustheitstest erstellen</br>
# ✅ Modellinterpretation erstellen</br>
# ✅ Sensitivitätsanalyse erstellen</br>
# ✅ Kommunikation (Key Takeaways)</br>

# %% [markdown]
# <p><font color='black' size="5">
# Prediction
# </font></p>

# %%
target_train_pred = model.predict(data_train)
target_test_pred = model.predict(data_test)

# %% [markdown]
# <p><font color='black' size="5">
# Bestimmtheitsmass
# </font></p>

# %%
r2 = r2_score(target_train, target_train_pred)
print(f'Modell: {model} -- Train --- Bestimmtheitsmass: {r2:5.2f}' )
# Out:
# Modell: RandomForestRegressor() -- Train --- Bestimmtheitsmass:  1.00

# %%
r2 = r2_score(target_test, target_test_pred)
print(f'Modell: {model} -- Test --- Bestimmtheitsmass: {r2:5.2f}' )
# Out:
# Modell: RandomForestRegressor() -- Test --- Bestimmtheitsmass:  0.98

# %% [markdown]
# <p><font color='black' size="5">
# Mean Absolut Error
# </font></p>

# %%
mae = mean_absolute_error(target_test, target_test_pred)
print(f'Modell: {model} -- Test -- Mean Absolute Error: {mae:5.2f}' )
# Out:
# Modell: RandomForestRegressor() -- Test -- Mean Absolute Error: 268.15

# %% [markdown]
# <p><font color='black' size="5">
# Aufbau Analysewürfel
# </font></p>

# %%
# Übernahme der Testdaten
cube = data_test.copy()
cube.reset_index(inplace=True)

# Übernahme Target real & predict
cube['real'] = pd.DataFrame(target_test.values, columns=['real'])
cube['predict'] = pd.DataFrame(target_test_pred, columns=['predict'])

# %%
# Erstellung 2D Features über Dimensionsreduktion PCA - unsupervised
pca = PCA(n_components=2)
pca = pca.fit_transform(data_test)
pca_df = pd.DataFrame(pca)

# Cube um pca erweitern
cube['PCA1'] = pca_df[0]
cube['PCA2'] = pca_df[1]

# %% [markdown]
# <p><font color='black' size="5">
# Visualisierung real vs predict
# </font></p>

# %%
# Boxplot
title_ = 'Boxplot real vs predict'
px.box(cube[['real', 'predict']], title=title_, width=600, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5d8cc24d-2020-42b2-83c5-8d02e5e2de14" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d8cc24d-2020-42b2-83c5-8d02e5e2de14")) {                    Plotly.newPlot(                        "5d8cc24d-2020-42b2-83c5-8d02e5e2de14",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real","real ...

# %%
# Histogramm
title_ = 'Histogramm Prices real vs predict'
fig = px.histogram(cube, x=['real', 'predict'], nbins=10, title=title_)
fig.update_layout(barmode='group',bargap=0.2, width=800, height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="

# Out:
# <style type="text/css">
# </style>
# <table id="T_0626c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0626c_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_0626c_level0_col1" class="col_heading level0 col1" >carat</th>
#       <th id="T_0626c_level0_col2" class="col_heading level0 col2" >cut</th>
#       <th id="T_0626c_level0_col3" class="col_heading level0 col3" >color</th>
#       <th id="T_0626c_level0_col4" class="col_heading level0 col4" >clarity</th>
#       <th id="T_0626c_level0_col5" class="col_heading level0 col5" >depth</th>
#       <th id="T_0626c_level0_col6" class="col_heading level0 col6" >table</th>
#       <th id="T_0626c_level0_col7" class="col_heading level0 col7" >x</th>
#       <th id="T_0626c_level0_col8" class="col_heading level0 col8" >y</th>
#       <th id="T_0626c_level0_col9" class="col_heading level0 col9" >z</th>
#       <th id="T_0626c_level0_col10" class="col_heading level0 col10" >real</th>
#       <th id="T_0626c_level0_col11" class="col_heading level0 col11" >predict</th>
#       <th id="T_0626c_level0_col12" class="col_heading level0 col12" >PCA1</th>
#       <th id="T_0626c_level0_col13" class="col_heading level0 col13" >PCA2</th>
#       <th id="T_0626c_level0_col14" class="col_heading level0 col14" >abs_Abw%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0626c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0626c_row0_col0" class="data row0 col0" >1388</td>
#       <td id="T_0626c_row0_col1" class="data row0 col1" >0.2</td>
#       <td id="T_0626c_row0_col2" class="data row0 col2" >4.000000</td>
#       <td id="T_0626c_row0_col3" class="data row0 col3" >3.000000</td>
#       <td id="T_0626c_row0_col4" class="data row0 col4" >6.000000</td>
#       <td id="T_0626c_row0_col5" class="data row0 col5" >62.1</td>
#       <td id="T_0626c_row0_col6" class="data row0 col6" >56.0</td>
#       <td id="T_0626c_row0_col7" class="data row0 col7" >4.0</td>
#       <td id="T_0626c_row0_col8" class="data row0 col8" >4.0</td>
#       <td id="T_0626c_row0_col9" class="data row0 col9" >2.5</td>
#       <td id="T_0626c_row0_col10" class="data row0 col10" >559</td>
#       <td id="T_0626c_row0_col11" class="data row0 col11" >554.400000</td>
#       <td id="T_0626c_row0_col12" class="data row0 col12" >-3.342795</td>
#       <td id="T_0626c_row0_col13" class="data row0 col13" >1.868095</td>
#       <td id="T_0626c_row0_col14" class="data row0 col14" >0.822898</td>
#     </tr>
#     <tr>
#       <th id="T_0626c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0626c_row1_col0" class="data row1 col0" >50052</td>
#       <td id="T_0626c_row1_col1" class="data row1 col1" >0.6</td>
#       <td id="T_0626c_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_0626c_row1_col3" class="data row1 col3" >4.000000</td>
#       <td id="T_0626c_row1_col4" class="data row1 col4" >5.000000</td>
#       <td id="T_0626c_row1_col5" class="data row1 col5" >60.0</td>
#       <td id="T_0626c_row1_col6" class="data row1 col6" >57.0</td>
#       <td id="T_0626c_row1_col7" class="data row1 col7" >5.4</td>
#       <td id="T_0626c_row1_col8" class="data row1 col8" >5.4</td>
#       <td id="T_0626c_row1_col9" class="data row1 col9" >3.3</td>
#       <td id="T_0626c_row1_col10" class="data row1 col10" >2201</td>
#       <td id="T_0626c_row1_col11" class="data row1 col11" >2381.110000</td>
#       <td id="T_0626c_row1_col12" class="data row1 col12" >-0.717214</td>
#       <td id="T_0626c_row1_col13" class="data row1 col13" >1.609831</td>
#       <td id="T_0626c_row1_col14" class="data row1 col14" >8.183099</td>
#     </tr>
#     <tr>
#       <th id="T_0626c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0626c_row2_col0" class="data row2 col0" >41645</td>
#       <td id="T_0626c_row2_col1" class="data row2 col1" >0.4</td>
#       <td id="T_0626c_row2_col2" class="data row2 col2" >4.000000</td>
#       <td id="T_0626c_row2_col3" class="data row2 col3" >5.000000</td>
#       <td id="T_0626c_row2_col4" class="data row2 col4" >5.000000</td>
#       <td id="T_0626c_row2_col5" class="data row2 col5" >62.1</td>
#       <td id="T_0626c_row2_col6" class="data row2 col6" >55.0</td>
#       <td id="T_0626c_row2_col7" class="data row2 col7" >4.8</td>
#       <td id="T_0626c_row2_col8" class="data row2 col8" >4.7</td>
#       <td id="T_0626c_row2_col9" class="data row2 col9" >3.0</td>
#       <td id="T_0626c_row2_col10" class="data row2 col10" >1238</td>
#       <td id="T_0626c_row2_col11" class="data row2 col11" >1211.410000</td>
#       <td id="T_0626c_row2_col12" class="data row2 col12" >-3.640683</td>
#       <td id="T_0626c_row2_col13" class="data row2 col13" >1.310047</td>
#       <td id="T_0626c_row2_col14" class="data row2 col14" >2.147819</td>
#     </tr>
#     <tr>
#       <th id="T_0626c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0626c_row3_col0" class="data row3 col0" >42377</td>
#       <td id="T_0626c_row3_col1" class="data row3 col1" >0.4</td>
#       <td id="T_0626c_row3_col2" class="data row3 col2" >3.000000</td>
#       <td id="T_0626c_row3_col3" class="data row3 col3" >5.000000</td>
#       <td id="T_0626c_row3_col4" class="data row3 col4" >5.000000</td>
#       <td id="T_0626c_row3_col5" class="data row3 col5" >60.8</td>
#       <td id="T_0626c_row3_col6" class="data row3 col6" >57.0</td>
#       <td id="T_0626c_row3_col7" class="data row3 col7" >4.9</td>
#       <td id="T_0626c_row3_col8" class="data row3 col8" >4.9</td>
#       <td id="T_0626c_row3_col9" class="data row3 col9" >3.0</td>
#       <td id="T_0626c_row3_col10" class="data row3 col10" >1304</td>
#       <td id="T_0626c_row3_col11" class="data row3 col11" >1223.580000</td>
#       <td id="T_0626c_row3_col12" class="data row3 col12" >-1.472540</td>
#       <td id="T_0626c_row3_col13" class="data row3 col13" >2.369265</td>
#       <td id="T_0626c_row3_col14" class="data row3 col14" >6.167178</td>
#     </tr>
#     <tr>
#       <th id="T_0626c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0626c_row4_col0" class="data row4 col0" >17244</td>
#       <td id="T_0626c_row4_col1" class="data row4 col1" >1.6</td>
#       <td id="T_0626c_row4_col2" class="data row4 col2" >4.000000</td>
#       <td id="T_0626c_row4_col3" class="data row4 col3" >5.000000</td>
#       <td id="T_0626c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_0626c_row4_col5" class="data row4 col5" >62.3</td>
#       <td id="T_0626c_row4_col6" class="data row4 col6" >55.0</td>
#       <td id="T_0626c_row4_col7" class="data row4 col7" >7.4</td>
#       <td id="T_0626c_row4_col8" class="data row4 col8" >7.4</td>
#       <td id="T_0626c_row4_col9" class="data row4 col9" >4.6</td>
#       <td id="T_0626c_row4_col10" class="data row4 col10" >6901</td>
#       <td id="T_0626c_row4_col11" class="data row4 col11" >9822.730000</td>
#       <td id="T_0626c_row4_col12" class="data row4 col12" >-0.894298</td>
#       <td id="T_0626c_row4_col13" class="data row4 col13" >-2.865671</td>
#       <td id="T_0626c_row4_col14" class="data row4 col14" >42.337777</td>
#     </tr>
#     <tr>
#       <th id="T_0626c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0626c_row5_col0" class="data row5 col0" >1608</td>
#       <td id="T_0626c_row5_col1" class="data row5 col1" >1.0</td>
#       <td id="T_0626c_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_0626c_row5_col3" class="data row5 col3" >5.000000</td>
#       <td id="T_0626c_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_0626c_row5_col5" class="data row5 col5" >55.4</td>
#       <td id="T_0626c_row5_col6" class="data row5 col6" >62.0</td>
#       <td id="T_0626c_row5_col7" class="data row5 col7" >6.6</td>
#       <td id="T_0626c_row5_col8" class="data row5 col8" >6.6</td>
#       <td id="T_0626c_row5_col9" class="data row5 col9" >3.7</td>
#       <td id="T_0626c_row5_col10" class="data row5 col10" >3011</td>
#       <td id="T_0626c_row5_col11" class="data row5 col11" >4034.090000</td>
#       <td id="T_0626c_row5_col12" class="data row5 co

# %%
cube.describe().T
# Out:
#             count          mean           std         min           25%  \
# index     16182.0  2.684652e+04  15590.947396    1.000000  13290.750000
# carat     16182.0  7.936856e-01      0.470375    0.200000      0.400000
# cut       16182.0  2.904833e+00      1.119779    0.000000      2.000000
# color     16182.0  3.408973e+00      1.702875    0.000000      2.000000
# clarity   16182.0  3.051106e+00      1.652282    0.000000      2.000000
# depth     16182.0  6.175986e+01      1.441881   43.000000     61.100000
# table     16182.0  5.744798e+01      2.252752   49.000000     56.000000
# x         16182.0  5.721311e+00      1.120562    0.000000      4.700000
# y         16182.0  5.724495e+00      1.131607    0.000000      4.710000
# z         16182.0  3.533092e+00      0.692098    0.000000      2.900000
# real      16182.0  3.889177e+03   3949.294519  326.000000    936.000000
# predict   16182.0  3.899822e+03   3930.775042  366.760000    936.425000
# PCA1      16182.0 -2.703066e-15      2.476391   -7.540924     -1.823348
# PCA2      16182.0 -1.297963e-15      1.982270  -10.251978     -1.333737
# abs_Abw%  16182.0  6.537470e+00      6.887998    0.000000      1.926003
#
#                    50%           75%           max
# index     26962.000000  40279.750000  53936.000000
# carat         0.700000      1.040000      4.010000
# cut           3.000000      4.000000      4.000000
# color         3.000000      5.000000      6.000000
# clarity       3.000000      4.000000      7.000000
# depth        61.900000     62.500000     79.000000
# table        57.000000     59.000000     73.000000
# x             5.690000      6.530000     10.140000
# y             5.710000      6.530000     31.800000
# z             3.520000      4.030000      6.310000
# real       2397.500000   5251.000000  18823.000000
# predict    2414.380000   5237.660000  18386.480000
# PCA1         -0.205133      1.586343     14.365111
# PCA2          0.080696      1.376011     10.591815
# abs_Abw%      4.510711      8.886062    103.833735

# %%
# Histogramm
title_ = 'Histogramm absolute Abweichung'
fig = px.histogram(cube, x=['abs_Abw%'], nbins=20, title=title_)
fig.update_layout(barmode='group',bargap=0.2, width=800, height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="
# %%
_ = residuals_plot(model, data_train, target_train, data_test, target_test, train_color='b', test_color='g')

# %%
_ = prediction_error(model, data_train,target_train, data_test, target_test)

# %% [markdown]
# <p><font color='black' size="5">
# Feature Importance
# </font></p>

# %%
px.bar(x=model.feature_importances_, y=data.columns, width=1000, height=600).update_yaxes(categoryorder="total ascending")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8a48b210-8330-4a7a-a915-d1cdd5d940a7" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a48b210-8330-4a7a-a915-d1cdd5d940a7")) {                    Plotly.newPlot(                        "8a48b210-8330-4a7a-a915-d1cdd5d940a7",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.6178852310296667,0.0017761205590643176,0.03139255018059577,0.06287632082977052,0.003089619862122043,0.0022534196777249825,0.005761277868928888,0.26976776153453763,0.005197698457589149],"xaxis":"x","y":["carat","cut","color","clarity","depth","table","x","y","z"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line" ...

# %%
_ = feature_importances(model, data, target)

# %% [markdown]
# # **5 <font color='orange'>|</font> Deploy**
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Modellexport und -speicherung</br>
# ✅ Abhängigkeiten und Umgebung</br>
# ✅ Sicherheit und Datenschutz</br>
# ✅ In die Produktion integrieren</br>
# ✅ Tests und Validierung</br>
# ✅ Dokumentation & Wartung</br>

# %% [markdown]
# <p><font size="5">
# Save - 2 Versionen
# </p>

# %%
# schnellste Variante
joblib.dump(model, '/content/diamonds-model.pkl')
# Out:
# ['/content/diamonds-model.pkl']

# %%
# save the model to PMML
# !pip install -q nyoka
# from nyoka import skl_to_pmml
# from sklearn.pipeline import Pipeline
# pipeline_ = Pipeline([('estimator', model)])
# skl_to_pmml(pipeline=pipeline_, col_names=data_test.columns, pmml_f_name='/content/diamonds-model.pmml')

# %% [markdown]
# <p><font color='black' size="5">
# Load - 2 Versionen
# </font></p>

# %%
import joblib
model_geladen = joblib.load('/content/diamonds-model.pkl')

# %%
# !pip install -q pypmml
# from pypmml import Model
# model_geladen = Model.fromFile('/content/diamonds-model.pmml')
# result = model.predict(data)

# %% [markdown]
# <p><font size="5">
# Prognose
# </p>

# %%
target_pred = model_geladen.predict(data_test)
r2 = r2_score(target_test, target_pred)
print (f'Bestimmheitsmaß Testdaten: {r2:.2f}')
# Out:
# Bestimmheitsmaß Testdaten: 0.98

# %%
result = pd.DataFrame()
result['real'] = target_test.values
result['pred'] = target_pred
result['%delta'] = (result['real'] - result['pred']) / result['real'] *100

# %%
pd.options.display.float_format = '{:.2f}'.format
result
# Out:
#         real     pred  %delta
# 0        559   554.40    0.82
# 1       2201  2381.11   -8.18
# 2       1238  1211.41    2.15
# 3       1304  1223.58    6.17
# 4       6901  9822.73  -42.34
# ...      ...      ...     ...
# 16177    705   747.98   -6.10
# 16178   5278  4810.01    8.87
# 16179  13157 12913.18    1.85
# 16180   2960  3244.38   -9.61
# 16181   1323  1303.38    1.48
#
# [16182 rows x 3 columns]
