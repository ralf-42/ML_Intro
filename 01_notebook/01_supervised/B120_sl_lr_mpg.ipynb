# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Machine Learning
# </b></font> </br></p>

# %% [markdown]
# <p><font size="5" color='grey'> <b>
# Supervised Learning - Linear Regression - Miles per Gallon
#
# ---

# %% [markdown]
# # 0  | Install & Import
# ---

# %%
# Install
# !uv pip install -q https://github.com/ydataai/ydata-profiling/archive/master.zip[notebook]

# %%
# Daten
from pandas import read_csv, DataFrame, Series

# Preprocessing
from sklearn.preprocessing import StandardScaler

# Modell
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Evaluation
from sklearn.metrics import r2_score, mean_absolute_error

# Visualisierung
import plotly.express as px

# Modell-Visualisierung / Analyse
from yellowbrick.regressor import residuals_plot

# %%
# Warnung ausstellen
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1  | Understand
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Aufgabe verstehen</br>
# ✅ Daten sammeln</br>
# ✅ Statistische Analyse (Min, Max, Mean, Korrelation, ...)</br>
# ✅ Datenvisualisierung (Streudiagramm, Box-Plot, ...)</br>
# ✅ Prepare Schritte festlegen</br>

# %% [markdown]
# <p><font color='black' size="5">
# Anwendungsfall
# </font></p>
#
# ---
#
# Die Daten betreffen den Kraftstoffverbrauch im Stadtverkehr in Meilen pro Gallone, der anhand fünf kontinuierlichen Attributen vorhergesagt werden kann.
#
#
#
# [DataSet](https://www.openml.org/search?type=data&status=active&id=42372)
#
# [Info](https://archive.ics.uci.edu/dataset/9/auto+mpg)

# %%
df = read_csv(
    "https://raw.githubusercontent.com/ralf-42/ML_Intro/main/02_daten/05_tabellen/auto_mpg.csv",
    usecols=[
        "mpg",
        "cylinders",
        "displacement",
        "horsepower",
        "weight",
        "acceleration",
        "model year",
        "origin",
    ],
)

# %%
data = df.copy()
target = data.pop("mpg")

# %% [markdown]
# <p><font color='black' size="5">
# EDA (Exploratory Data Analysis) mit Pandas
# </font></p>

# %%
data.info()

# %%
data.describe().T

# %% [markdown]
# <p><font color='black' size="5">
# EDA - Profiling Report
# </font></p>

# %%
# Import
import numpy as np
from ydata_profiling import ProfileReport

# %%
# Bericht erstellen und als html speichern
profile_report = ProfileReport(df, explorative=True, html={"style": {"full_width": True}})
profile_report.to_file("eda_report.html")
profile_report

# %% [markdown]
# # 2 |  Prepare
#
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Datentyp ermitteln/ändern</br>
# ✅ Train-Test-Split durchführen</br>
# ✅ Nicht benötigte Features löschen</br>
# ✅ Missing Values behandeln</br>
# ✅ Ausreißer behandeln</br>
# ✅ Kategorischer Features Kodieren</br>
# ✅ Numerischer Features skalieren</br>
# ✅ Feature-Engineering (neue Features schaffen)</br>
# ✅ Dimensionalität reduzieren</br>
# ✅ Resampling (Over-/Undersampling)</br>
# ✅ Pipeline erstellen/konfigurieren</br>

# %% [markdown]
# <p><font color='black' size="5">
# Ungültige Angaben
# </font></p>

# %%
data = data[data.horsepower != "?"]

# %%
data.horsepower = data.horsepower.astype(int)

# %%
target = target[data.index]

# %% [markdown]
# <p><font color='black' size="5">
# Datentyp ermitteln
# </font></p>

# %%
all_col = data.columns
num_col = data.select_dtypes(include="number").columns
cat_col = data.select_dtypes(exclude="number").columns

# %% [markdown]
# <p><font color='black' size="5">
# Train-Test-Split
# </font></p>

# %%
data_train, data_test, target_train, target_test = train_test_split(
    data, target, test_size=0.2, random_state=42)

# %% [markdown]
# <p><font color='black' size="5">
# Skalierung
# </font></p>

# %%
scaler = StandardScaler()
scaler.fit(data_train[all_col])
data_train[all_col] = scaler.transform(data_train[all_col])
data_test[all_col] = scaler.transform(data_test[all_col])

# %% [markdown]
# # 3 |  Modeling
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Modellauswahl treffen</br>
# ✅ Pipeline erweitern/konfigurieren</br>
# ✅ Training durchführen</br>
# ✅ Hyperparameter Tuning</br>
# ✅ Cross-Validiation</br>
# ✅ Bootstrapping</br>
# ✅ Regularization</br>

# %% [markdown]
# <p><font color='black' size="5">📈 Algorithmus: Lineare Regression</font></p>
#
# Die **lineare Regression** sucht nach dem besten linearen Zusammenhang zwischen Eingabevariablen (z.B. Gewicht, Hubraum) und einem Zielwert (z.B. Kraftstoffverbrauch in MPG). Das Modell lernt Koeffizienten, die beschreiben, wie stark jedes Merkmal die Vorhersage beeinflusst.
#
# **Analogie:** Ist bekannt, dass schwerere Autos mehr verbrauchen, lässt sich allein aus dem Gewicht auf den Verbrauch schließen. Die lineare Regression findet genau diese Linie – und berücksichtigt dabei alle Merkmale gleichzeitig.
#
# **Im MPG-Beispiel:**
# - Eingabe: Technische Merkmale (Hubraum, Zylinder, Gewicht, Leistung, ...)
# - Ausgabe: Kraftstoffverbrauch (Miles per Gallon)
# - Das Modell lernt: Je schwerer das Auto, desto niedriger der MPG-Wert
#
# **Wichtige Begriffe:**
#
# | Begriff | Bedeutung |
# |---------|----------|
# | Koeffizient | Einfluss eines Merkmals auf die Vorhersage |
# | Intercept | Basiswert, wenn alle Merkmale = 0 |
# | R² | Anteil der erklärten Varianz (0 = schlecht, 1 = perfekt) |
# | MSE / RMSE | Durchschnittlicher Vorhersagefehler |

# %% [markdown]
# **In der Praxis relevant wenn:**
# - Der Zielwert eine kontinuierliche Zahl ist (z.B. Preis, Verbrauch, Temperatur)
# - Ein linearer Zusammenhang zwischen Merkmalen und Zielwert plausibel ist
# - Die Koeffizienten als Erklärung gebraucht werden (welches Merkmal beeinflusst den Wert wie stark?)
# - Ein schnelles Basismodell für Regressionsprobleme gebraucht wird
#
# **Nicht geeignet wenn:**
# - Der Zielwert kategorisch ist → dann Logistische Regression oder Decision Tree
# - Starke nichtlineare Zusammenhänge vorliegen → dann Random Forest oder XGBoost
#
# **Typischer Fehler:**
# - Skalierung vergessen — Features mit sehr unterschiedlichen Einheiten (z.B. Gewicht in kg vs. Zylinder 4–8) verzerren die Koeffizienten. Vor der Linearen Regression immer skalieren.

# %%
#@markdown   <p><font size="4" color='green'>  Lineare Regression</font> </br></p>

import base64
from IPython.display import Image, display

diagram = """
flowchart LR
    MERKMALE[Eingabe: Hubraum, Gewicht, ...] --> MODELL[Lineare Regression]
    TRAIN[Trainingsdaten] --> LERNEN[Lernphase: Koeffizienten anpassen]
    LERNEN --> MODELL
    MODELL --> PRED[Vorhersage: MPG-Wert]
"""

encoded = base64.urlsafe_b64encode(diagram.strip().encode()).decode()
display(Image(url=f"https://mermaid.ink/img/{encoded}", width=750))

# %% [markdown]
#  <p><font color='black' size="5">
# Modellauswahl & Training
# </font></p>

# %%
model = LinearRegression()

# %%
model.fit(data_train, target_train)

# %% [markdown]
# # 4 | Evaluate
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Prognose (Train, Test) erstellen</br>
# ✅ Modellgüte prüfen</br>
# ✅ Residuenanalyse erstellen</br>
# ✅ Feature Importance/Selektion prüfen</br>
# ✅ Robustheitstest erstellen</br>
# ✅ Modellinterpretation erstellen</br>
# ✅ Sensitivitätsanalyse erstellen</br>
# ✅ Kommunikation (Key Takeaways)</br>

# %% [markdown]
# <p><font color='black' size="5">
# Prediction
# </font></p>

# %%
target_train_pred = model.predict(data_train)
target_test_pred = model.predict(data_test)

# %% [markdown]
# <p><font color='black' size="5">
# Bestimmtheitsmass
# </font></p>

# %%
r2 = r2_score(target_train, target_train_pred)
print(f"Modell: {model} -- Train --- Bestimmtheitsmass: {r2:5.2f}")

# %%
r2 = r2_score(target_test, target_test_pred)
print(f"Modell: {model} -- Test --- Bestimmtheitsmass: {r2:5.2f}")

# %% [markdown]
# <p><font color='black' size="5">
# Mean Absolut Error
# </font></p>

# %%
mae = mean_absolute_error(target_test, target_test_pred)
print(f"Modell: {model} -- Test -- Mean Absolute Error: {mae:5.2f}")

# %%
min(target_test), max(target_test)

# %% [markdown]
# <p><font color='black' size="5">
# Ursprung
# </font></p>

# %%
model.intercept_

# %% [markdown]
# <p><font color='black' size="5">
# Koeffizienten (Importance)
# </font></p>

# %%
model.coef_

# %% [markdown]
# <p><font color='black' size="5">
# Aufbau Analysewürfel
# </font></p>

# %%
# Übernahme der Testdaten
cube = data_test.copy()
cube.reset_index(inplace=True)

# Übernahme Target real & predict
cube["real"] = target_test.values
cube["predict"] = target_test_pred

# %% [markdown]
# <p><font color='black' size="5">
# Visualisierung real vs predict
# </font></p>

# %%
# Boxplot
title_ = "Boxplot real vs predict"
px.box(cube[["real", "predict"]], title=title_, width=600, height=600)

# %%
# Histogramm
title_ = "Histogramm Prices real vs predict"
fig = px.histogram(cube, x=["real", "predict"], nbins=10, title=title_)
fig.update_layout(barmode="group", bargap=0.2, width=800, height=600)
fig.show()

# %% [markdown]
# <p><font color='black' size="5">
# Fehlerhafte Vorhersagen
# </font></p>

# %%
cube["abs_Abw%"] = abs((cube["real"] - cube["predict"]) / cube["real"] * 100)

# %%
cube.describe().T

# %%
# Histogramm
title_ = "Histogramm absolute Abweichung"
fig = px.histogram(cube, x=["abs_Abw%"], nbins=10, title=title_)
fig.update_layout(barmode="group", bargap=0.2, width=800, height=600)
fig.show()

# %%
_ = residuals_plot(
    model,
    data_train,
    target_train,
    data_test,
    target_test,
    train_color="b",
    test_color="g",
)

# %% [markdown]
# # 5 | Deploy
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Modellexport und -speicherung</br>
# ✅ Abhängigkeiten und Umgebung</br>
# ✅ Sicherheit und Datenschutz</br>
# ✅ In die Produktion integrieren</br>
# ✅ Tests und Validierung</br>
# ✅ Dokumentation & Wartung</br>
