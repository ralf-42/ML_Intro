# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Machine Learning
# </b></font> </br></p>

# %% [markdown]
# <p><font size="5" color='grey'> <b>
# Ensemble - Stacking 3+1 - Titanic
# </b></font> </br></p>
#
# ---

# %% [markdown]
# # 0  | Install & Import
# ***

# %%
# Install

# %%
# Daten
from pandas import read_excel, DataFrame
import numpy as np

# Preprocessing
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler

# Modellvorbereitung
from sklearn.model_selection import train_test_split

# Basismodelle (für Stacking)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

# Meta-Modell / Ensemble
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier

# Evaluation
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    classification_report,
)

# %%
# Warnung ausstellen
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1  | Understand
# ***

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Aufgabe verstehen</br>
# ✅ Daten sammeln</br>
# ✅ Statistische Analyse (Min, Max, Mean, Korrelation, ...)</br>
# ✅ Datenvisualisierung (Streudiagramm, Box-Plot, ...)</br>
# ✅ Prepare Schritte festlegen</br>

# %% [markdown]
# <p><font color='black' size="5">
# Anwendungsfall
# </font></p>
#
# Dies ist der legendäre Titanic ML-Wettbewerb – die beste erste Herausforderung, um in ML-Modellierung einzutauchen.
#
# Die Aufgabe ist einfach: Mit maschinellem Lernen lässt sich ein Modell erstellen, das vorhersagt, welche Passagiere den Schiffbruch der Titanic überlebt haben.
#
# [Titanic Org](https://www.encyclopedia-titanica.org/)
#
# [DataSet](https://www.openml.org/search?type=data&status=active&id=40945)
#
# [Info](https://www.kaggle.com/competitions/titanic/data)

# %%
df = read_excel(
    "https://raw.githubusercontent.com/ralf-42/ML_Intro/main/02_daten/05_tabellen/titanic.xlsx",
    usecols=["pclass", "survived", "sex", "age", "sibsp", "parch"],
)

# %%
data = df.copy()
target = data.pop("survived")

# %% [markdown]
# <p><font color='black' size="5">
# EDA (Exploratory Data Analysis) mit Pandas
# </font></p>

# %%
data.info()

# %%
data.describe().T

# %%
data.groupby("pclass").count()

# %%
target.value_counts()

# %%
# _ = data.hist(figsize=(15,15))

# %% [markdown]
# #  2 | Prepare

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Train-Test-Split durchführen</br>
# ✅ Nicht benötigte Features löschen</br>
# ✅ Datentyp ermitteln/ändern</br>
# ✅ Missing Values behandeln</br>
# ✅ Ausreißer behandeln</br>
# ✅ Kategorischer Features Kodieren</br>
# ✅ Numerischer Features skalieren</br>
# ✅ Feature-Engineering (neue Features schaffen)</br>
# ✅ Dimensionalität reduzieren</br>
# ✅ Resampling (Over-/Undersampling)</br>
# ✅ Pipeline erstellen/konfigurieren</br>

# %% [markdown]
# <font color='black' size="5">
# Datentyp ermitteln
# </font>

# %%
all_col = data.columns
num_col = data.select_dtypes(include="number").columns
cat_col = data.select_dtypes(exclude="number").columns

# %% [markdown]
# <font color='black' size="5">
# Train-Test-Set
# </font>

# %%
data_train, data_test, target_train, target_test = train_test_split(
    data, target, test_size=0.20, stratify=target, random_state=42)

# %% [markdown]
# <font color='black' size="5">
# Missing Values - kategoriale Features
# </font>

# %%
imputer_cat = SimpleImputer(strategy="most_frequent")
imputer_cat.fit(data_train[cat_col])
data_train[cat_col] = imputer_cat.transform(data_train[cat_col])
data_test[cat_col] = imputer_cat.transform(data_test[cat_col])

# %% [markdown]
# <font color='black' size="5">
# Kodierung
# </font>

# %%
encoder = OrdinalEncoder()
encoder.fit(data_train[cat_col])
data_train[cat_col] = encoder.transform(data_train[cat_col])
data_test[cat_col] = encoder.transform(data_test[cat_col])

# %% [markdown]
# <font color='black' size="5">
# Missing Values - numerische Features
# </font>

# %%
imputer_num = SimpleImputer(strategy="mean")
imputer_num.fit(data_train[num_col])
data_train[num_col] = imputer_num.transform(data_train[num_col])
data_test[num_col] = imputer_num.transform(data_test[num_col])

# %% [markdown]
# <font color='black' size="5">
# Skalierung
# </font>

# %%
scaler = StandardScaler()
scaler.fit(data_train[all_col])
data_train[all_col] = scaler.transform(data_train[all_col])
data_test[all_col] = scaler.transform(data_test[all_col])

# %% [markdown]
# # 3 | Modeling
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Modellauswahl treffen</br>
# ✅ Pipeline erweitern/konfigurieren</br>
# ✅ Training durchführen</br>
# ✅ Hyperparameter Tuning</br>
# ✅ Cross-Valdiation</br>
# ✅ Bootstrapping</br>
# ✅ Regularization</br>

# %% [markdown]
# <p><font color='black' size="5">🏗️ Algorithmus: Stacking (Gestapeltes Ensemble)</font></p>
#
# Beim Stacking werden mehrere unterschiedliche Basismodelle (Base Learner) parallel trainiert. Ihre Vorhersagen werden anschließend als neue Merkmale für ein Meta-Modell (Meta Learner) verwendet, das die finale Entscheidung trifft.
#
# **Analogie:** Mehrere Experten geben unabhängig ihre Einschätzung ab – ein übergeordneter Entscheider kombiniert ihre Meinungen zur optimalen Lösung.
#
# **Wichtige Begriffe:**
#
# | Begriff | Bedeutung |
# |---------|----------|
# | Base Learner | Verschiedene Basismodelle (z.B. DT, KNN, SVM) |
# | Meta Learner | Modell, das die Vorhersagen kombiniert |
# | `final_estimator` | Parameter für das Meta-Modell in scikit-learn |

# %% [markdown]
# **In der Praxis relevant wenn:**
# - Mehrere unterschiedliche Modelle einzeln gute Ergebnisse liefern und deren Stärken kombiniert werden sollen
# - Maximale Genauigkeit wichtiger ist als Rechenzeit oder Einfachheit der Architektur
# - Die Basismodelle strukturell unterschiedlich sind (z.B. DT + KNN + SVM) — ähnliche Modelle bringen beim Stacking kaum Mehrwert
#
# **Nicht geeignet wenn:**
# - Rechenzeit kritisch ist → Stacking trainiert alle Basismodelle mehrfach über Cross-Validation (Out-of-Fold)
# - Nur ein einziger Modelltyp zur Verfügung steht → dann einfaches Bagging oder Boosting
#
# **Typischer Fehler:**
# Alle Basismodelle vom gleichen Typ wählen (z.B. drei verschiedene Entscheidungsbäume) — dann lernt der Meta Learner aus sehr ähnlichen Vorhersagen. Diversität ist der Schlüssel: unterschiedliche Algorithmen liefern unterschiedliche Fehler, die der Meta Learner besser kombinieren kann.

# %%
#@markdown   <p><font size="4" color='green'>  Stacking – Ensemble-Struktur</font> </br></p>

import base64
from IPython.display import Image, display

diagram = """
flowchart TD
    DATA[Trainingsdaten] --> SPLIT[Cross-Validation Splits]

    SPLIT --> B1[Base Learner 1]
    SPLIT --> B2[Base Learner 2]
    SPLIT --> B3[Base Learner 3]

    B1 --> P1[OOF Predictions 1]
    B2 --> P2[OOF Predictions 2]
    B3 --> P3[OOF Predictions 3]

    P1 --> META[Meta Learner]
    P2 --> META
    P3 --> META

    META --> OUT[Finale Vorhersage]
"""

encoded = base64.urlsafe_b64encode(diagram.strip().encode()).decode()
display(Image(url=f"https://mermaid.ink/img/{encoded}", width=550))

# %% [markdown]
# <p><font color='black' size="5">
# Aufbau Ensemble
# </font></p>

# %%
model_list = [
    ("rf", RandomForestClassifier(n_estimators=10, random_state=42)),
    ("knn", KNeighborsClassifier()),
    ("svc", LinearSVC(random_state=42)),
]

meta_learner = LogisticRegression()

# %%
model = StackingClassifier(estimators=model_list, final_estimator=meta_learner)

# %%
model.fit(data_train, target_train)

# %% [markdown]
# # 4 | Evaluate
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Prognose (Train, Test) erstellen</br>
# ✅ Modellgüte prüfen</br>
# ✅ Residuenanalyse erstellen</br>
# ✅ Feature Importance/Selektion prüfen</br>
# ✅ Robustheitstest erstellen</br>
# ✅ Modellinterpretation erstellen</br>
# ✅ Sensitivitätsanalyse erstellen</br>
# ✅ Kommunikation (Key Takeaways)</br>

# %% [markdown]
# <p><font color='black' size="5">
# Prognose
# </font></p>

# %%
target_train_pred = model.predict(data_train)
target_test_pred = model.predict(data_test)

# %% [markdown]
# <p><font color='black' size="5">
# Accuracy
# </font></p>

# %%
acc_train = accuracy_score(target_train, target_train_pred) * 100
print(f"-- Train -- Accuracy: {acc_train:5.2f}")

# %%
acc_test = accuracy_score(target_test, target_test_pred) * 100
print(f"-- Test -- Accuracy: {acc_test:5.2f}")

# %% [markdown]
# <p><font color='black' size="5">
# Confusion Matrix
# </font></p>

# %%
conf_matrix = confusion_matrix(target_test, target_test_pred)
disp = ConfusionMatrixDisplay(conf_matrix, display_labels=["Not Survived", "Survived"])
disp.plot(cmap="Blues")

# %%
print(
    classification_report(
        target_test, target_test_pred, target_names=["Not Survived", "Survived"]
    )
)

# %% [markdown]
# # 5 | Deploy
# ---

# %% [markdown]
# <p><font color='black' size="5">📋 Checkliste</font></p>
#
# ✅ Modellexport und -speicherung</br>
# ✅ Abhängigkeiten und Umgebung</br>
# ✅ Sicherheit und Datenschutz</br>
# ✅ In die Produktion integrieren</br>
# ✅ Tests und Validierung</br>
# ✅ Dokumentation & Wartung</br>
