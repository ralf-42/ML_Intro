# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_deep_learning/blob/main/assignments/assignment_yourname_class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="In Colab öffnen"/></a>

# %% [markdown]
# # T81-558: Anwendungen tiefer neuronaler Netzwerke
# * Dozent: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Jeff Heaton](https://sites.wustl.edu/jeffheaton/)
# * Weitere Informationen finden Sie unter [class website](https://sites.wustl.edu/jeffheaton/t81-558/).
#
# **Modul 1-Aufgabe: So reichen Sie eine Aufgabe ein**
#
# **Name des Studenten: Ihr Name**

# %% [markdown]
# # Aufgabenanweisungen
#
# Aufgaben werden mit der Funktion **Submit** übermittelt, die weiter oben in diesem Dokument definiert wurde. Wenn Sie eine Aufgabe übermitteln, senden Sie sowohl Ihren Quellcode als auch Ihre Daten. Ein Computerprogramm überprüft Ihre Daten automatisch und informiert Sie
# wie gut Ihre Daten mit meiner Lösungsdatei übereinstimmen. Sie dürfen so oft einreichen, wie Sie möchten. Wenn Sie also bei Ihrer ersten Einreichung Probleme feststellen, dürfen Sie Änderungen vornehmen und die Arbeit erneut einreichen. Sie können so oft erneut einreichen, wie Sie möchten. Ich berücksichtige nur Ihre letzte Einreichung bei der Bewertung.
#
# Als Sie sich zum ersten Mal für den Kurs angemeldet haben, habe ich Ihnen per E-Mail einen Studentenschlüssel geschickt. Unten sehen Sie einen Beispielschlüssel. Wenn Sie diesen Schlüssel verwenden, wird eine Fehlermeldung angezeigt. Es ist nicht der aktuelle Schlüssel. **Verwenden Sie IHREN Studentenschlüssel, den ich Ihnen in der E-Mail mitgeteilt habe.**
#
# Sie müssen außerdem einen Dateinamen und eine Auftragsnummer angeben. Der Dateiname ist die Quelldatei, die Sie übermitteln möchten. Ihre Daten sind ein Pandas-Datenrahmen.
#
# **Aufgabe 1 ist einfach!** Um Aufgabe 1 abzuschließen, müssen Sie nur Ihren Studentenschlüssel hinzufügen und sicherstellen, dass die Variable **file** den Pfad zu Ihrer Quelldatei enthält. Ihre Quelldatei endet höchstwahrscheinlich mit **.pynb**, wenn Sie ein Jupyter-Notebook verwenden. Sie kann jedoch auch mit **.py** enden, wenn Sie ein Python-Skript verwenden.
#
# Führen Sie den unten stehenden Code aus. Wenn er erfolgreich ist, sollte ungefähr Folgendes angezeigt werden:
#
# ```
# Success: Submitted assignment 1 for jheaton:
# You have submitted this assignment 2 times. (this is fine)
# No warnings on your data. You will probably do well, but no guarantee. :-)
# ```
#
# Wenn es ein Problem mit Ihren Daten gibt, erhalten Sie eine Warnung.
#
#
# **Häufiges Problem Nr. 1: Falscher Studentenschlüssel**
#
# Wenn Sie einen ungültigen Studierendenschlüssel verwenden, wird Ihnen Folgendes angezeigt:
#
# ```
# Failure: {"message":"Forbidden"}
# ```
#
# Sie sollten auch sicherstellen, dass **_class#** irgendwo in Ihrem Dateinamen vorkommt. Beispielsweise sollte bei Aufgabe 1 **_class1** irgendwo in Ihrem Dateinamen vorkommen. Andernfalls erhalten Sie eine Fehlermeldung. Diese Überprüfung stellt sicher, dass Sie nicht die falsche Aufgabe mit der falschen Datei einreichen. Wenn es eine Nichtübereinstimmung gibt, erhalten Sie eine Fehlermeldung wie:
#
#
# **Häufiges Problem Nr. 2: Der Dateiname muss class1 (oder eine andere Nummer) enthalten**
# ```
# Exception: _class1 must be part of the filename.
# ```
#
# Das folgende Video befasst sich mit der Abgabe von Aufgaben: [assignment submission video](http://www.yahoo.com).
#
# **Häufiges Problem Nr. 3: Quelldatei kann nicht gefunden werden**
#
# Möglicherweise wird eine Fehlermeldung ähnlich dieser angezeigt:
#
# ```
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jeffh/projects/t81_558_deep_learning/t81_558_class1_intro_python.ipynb'
# ```
#
# Dieser Fehler bedeutet, dass Ihr **Datei**-Pfad falsch ist. Stellen Sie sicher, dass der Pfad mit dem Speicherort Ihrer Datei übereinstimmt. Beachten Sie meine Hinweise unten in den Kommentaren zu Pfaden in verschiedenen Umgebungen.
#
# **Häufiges Problem Nr. 4: Zu viele Daten**
#
# Möglicherweise wird eine Fehlermeldung ähnlich dieser angezeigt:
#
# ```
# Failure: HTTP content length exceeded 10485760 bytes.
# ```
#
# Ich sehe diesen Fehler manchmal. Grundsätzlich lässt AWS Lambda nur eine bestimmte Größe der HTTP-Anfrage zu. Alle meine Zuweisungen bleiben deutlich unter dem von Ihnen erreichten Limit. Das bedeutet, dass die von Ihnen generierte Datenmenge weit genug über dem liegt, was ich erlebe, sodass Sie diesen Fehler erhalten. Ich würde mir die Anzahl der von Ihnen generierten Zeilen ansehen.
#
# **Häufiges Problem Nr. 5: Fehler: „Diese Zuweisung erwartet CSV-Daten, Sie haben keinen Datenrahmen gesendet.“**
#
# Wenn der Fehler angezeigt wird:
#
# ```
# Failure: "This assignment expects CSV data, you did not send a data frame."
# ```
#
# Dies liegt normalerweise daran, dass Sie keine eckigen Klammern um den Datenrahmen haben, den Sie übermitteln. Stattdessen:
#
# ```
# submit(source_file=file,data=df,key=key,no=1)
# ```
#
# Stellen Sie sicher, dass Sie über Folgendes verfügen:
#
# ```
# submit(source_file=file,data=[df],key=key,no=1)
# ```
# Möglicherweise übermitteln Sie auch keinen Datenrahmen. Versuchen Sie, den Typ des Datenrahmens auszudrucken, den Sie übermitteln, zum Beispiel:
#
# ```
# print(type(df))
# submit(source_file=file,data=[df],key=key,no=1)
# ```
# **Häufiges Problem Nr. 6: Google Drive ist deaktiviert**
#
# Wenn Sie versuchen, Ihr Google Drive zuzuordnen, wird Ihnen mitgeteilt, dass es deaktiviert ist. Dies ist eine WUSTL-Einstellung für @wustl.edu-E-Mail-Konten. Aus irgendeinem Grund können Sie Google Drive auf CoLab nicht in Verbindung mit WUSTL-E-Mail-Konten verwenden. Verwenden Sie ein Nicht-WUSTL-E-Mail-Konto.
#
# **Häufiges Problem Nr. 7: Der geheime Schlüssel T81_558_KEY existiert nicht**
#
# Sie müssen Ihren Übermittlungsschlüssel in Google CoLab unter dem „Schlüsselsymbol“ definieren, siehe Video zu Modul 1.
#
# ```
# Mounted at /content/drive
# Note: using Google CoLab
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1fa45d638be1> in <cell line: 12>()
#      12 if COLAB:
#      13   # For Colab, add to your "Secrets" (key icon at the left)
# ---> 14   key = userdata.get('T81_558_KEY')
#      15 else:
#      16   # If not colab, enter your key here, or use an environment variable.
#
# /usr/local/lib/python3.10/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret T81_558_KEY does not exist.
# ```
#
# **Häufiges Problem Nr. 8: ???**
#
# Wenn Sie auf ein Problem stoßen, das hier nicht aufgeführt ist, lassen Sie es mich einfach wissen. Wenn Sie den Fehler „Datei nicht gefunden“ nicht beheben können, versuchen Sie, den Code auszuführen, der weiter unten in dieser Datei angegeben ist, um alle Dateien in Ihrem Notizbuchordner aufzulisten.

# %% [markdown]
# # Google CoLab-Anweisungen
#
# Wenn Sie Google CoLab verwenden, müssen Sie Ihr GDrive mounten, damit Sie Ihr Notebook während des Übermittlungsvorgangs senden können. Wenn Sie den folgenden Code ausführen, wird Ihr GDrive ```/content/drive``` zugeordnet.

# %%
try:
    from google.colab import drive, userdata

    drive.mount("/content/drive", force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# Schlüssel zur Aufgabenabgabe – wurde Ihnen in der ersten Unterrichtswoche zugesandt.
# Wenn Sie in beiden Klassen sind, ist dies derselbe Schlüssel.
if COLAB:
    # Für Colab fügen Sie zu Ihren „Geheimnissen“ hinzu (Schlüsselsymbol links)
    key = userdata.get("T81_558_KEY")
else:
    # Wenn es sich nicht um Colab handelt, geben Sie hier Ihren Schlüssel ein oder verwenden Sie eine Umgebungsvariable.
    # (das ist nur ein Beispielschlüssel, verwenden Sie Ihren)
    key = "Gx5en9cEVvaZnjhdaushddhuhhO4PsI32sgldAXj"

# %% [markdown]
# Wenn Sie dieses Notebook mit CoLab ausführen, zeigt Ihnen der folgende Befehl Ihre Notebooks an. Sie müssen den Speicherort Ihres Notebooks kennen, wenn Sie Ihre Aufgabe übermitteln.

# %%
# !ls /content/drive/My\ Drive/Colab\ Notebooks

# %% [markdown]
# # Funktion zum Übermitteln von Aufgaben
#
# Sie reichen die zehn Programmieraufgaben elektronisch ein. Hierzu können Sie die folgende **Submit**-Funktion verwenden. Mein Server führt eine Grundprüfung jeder Aufgabe durch und informiert Sie, wenn er irgendwelche zugrunde liegenden Probleme erkennt.
#
# **Es ist unwahrscheinlich, dass diese Funktion geändert werden muss.**

# %%
import base64
import os
import numpy as np
import pandas as pd
import requests
import PIL
import PIL.Image
import io
from typing import List, Union

# Mit dieser Funktion können Sie eine Aufgabe einreichen. Sie können eine Aufgabe so oft einreichen, wie Sie möchten, nur die endgültige
# Die Anzahl der Einreichungen. Die Parameter sind wie folgt:
# Daten – Liste von Pandas-Datenrahmen oder -Bildern.
# Schlüssel – Ihr Studentenschlüssel, der Ihnen per E-Mail zugeschickt wurde.
# Kurs – Der Kurs, an dem Sie teilnehmen, derzeit t81-558 oder t81-559.
# nein – Die Zuweisungsklassennummer sollte zwischen 1 und 1 liegen.
# Quelldatei – Der vollständige Pfad zu Ihrer Python- oder IPYNB-Datei. Der Name muss „_class1“ enthalten.
# . Die Nummer muss mit Ihrer Aufgabennummer übereinstimmen. Zum Beispiel „_class2“ für Klassenaufgabe Nr. 2.

def submit(
    data: List[Union[DataFrame, PIL.Image.Image]],
    key: str,
    course: str,
    no: int,
    source_file: str = None
) -> None:
    if source_file is None and '__file__' not in globals():
        raise Exception("Must specify a filename when in a Jupyter notebook.")
    if source_file is None:
        source_file = __file__

    suffix = f'_class{no}'
    if suffix not in source_file:
        raise Exception(f"{suffix} must be part of the filename.")

    ext = os.path.splitext(source_file)[-1].lower()
    if ext not in ['.ipynb', '.py']:
        raise Exception(f"Source file is {ext}; must be .py or .ipynb")

    with open(source_file, "rb") as file:
        encoded_python = base64.b64encode(file.read()).decode('ascii')

    payload = []
    for item in data:
        if isinstance(item, PIL.Image.Image):
            buffered = io.BytesIO()
            item.save(buffered, format="PNG")
            payload.append({'PNG': base64.b64encode(buffered.getvalue()).decode('ascii')})
        elif isinstance(item, DataFrame):
            payload.append({'CSV': base64.b64encode(item.to_csv(index=False).encode('ascii')).decode("ascii")})
        else:
            raise ValueError(f"Unsupported data type: {type(item)}")

    response = requests.post(
        "https://api.heatonresearch.com/wu/submit",
        headers={'x-api-key': key},
        json={
            'payload': payload,
            'assignment': no,
            'course': course,
            'ext': ext,
            'py': encoded_python
        }
    )

    if response.status_code == 200:
print(f"Erfolg: {response.text}")
    else:
print(f"Fehler: {response.text}")

# %% [markdown]
# # Aufgabe Nr. 1 Beispielcode
#
# Für Aufgabe Nr. 1 müssen Sie nur zwei Dinge ändern. Der Schlüssel muss so geändert werden, dass er Ihr Schlüssel ist, und der Dateipfad muss so geändert werden, dass er der Pfad zu Ihrer lokalen Datei ist. Sobald Sie das haben, führen Sie es einfach aus, und Ihre Aufgabe wird übermittelt.

# %%
# Sie müssen Ihre Quelldatei identifizieren. (für Ihr lokales Setup ändern)
file = "/content/drive/My Drive/Colab Notebooks/assignment_yourname_t81_558_class1.ipynb"  # Google CoLab
# Datei = 'C:\\Benutzer\\jeffh\\Projekte\\t81_558_deep_learning\\Aufgaben\\Aufgabe_IhrName_Klasse1.ipynb' # Windows
# Datei = "/Benutzer/jheaton/Projekte/t81_558_deep_learning/assignments/assignment_IhrName_Klasse1.ipynb" # Mac/Linux

df = DataFrame({"a": [1, 0, 1, 1], "b": [0, 1, 0, 1], "c": [0, 1, 1, 0]})

submit(source_file=file, data=[df], key=key, course="t81-558", no=1)

# %% [markdown]
# # Überprüfung Ihrer Einreichung
#
# Sie können jederzeit überprüfen, ob mein Programm Ihre Eingabe korrekt empfangen hat. Der folgende Hilfscode hilft Ihnen dabei.

# %%
import requests
import pandas as pd
import base64
import os


def list_submits(key, course):
    r = requests.post(
        "https://api.heatonresearch.com/wu/submit",
        headers={"x-api-key": key},
        json={"course": course},
    )
    if r.status_code == 200:
        print("Success: \n{}".format(r.text))
    else:
        print("Failure: {}".format(r.text))


def display_submit(key, no, course):
    r = requests.post(
        "https://api.heatonresearch.com/wu/submit",
        headers={"x-api-key": key},
        json={"course": course, "assignment": no},
    )
    if r.status_code == 200:
        print("Success: \n{}".format(r.text))
    else:
        print("Failure: {}".format(r.text))

# %%
# Zeigt eine Liste aller abgegebenen Aufgaben an.

list_submits(key, course="t81-558")

# %%
# Zeigen Sie eine Aufgabe nach Nummer.

display_submit(key, 1, course="t81-558")

# %% [markdown]
# # Sie können Ihre Datei nicht in CoLab finden?
#
# Der folgende Code listet alle Dateien in Ihrem Google Colab Notebooks-Verzeichnis zusammen mit einem True/False-Indikator auf, der angibt, ob die Datei geöffnet werden konnte. Sie SOLLTEN alle True-Werte sehen. Kopieren/fügen Sie den Dateinamen (zusammen mit den Anführungszeichen) ein und verwenden Sie ihn als Namen Ihres übermittelten Notizbuchs.

# %%
from os import listdir
from os.path import isfile, join
import base64

if COLAB:
  PATH = "/content/drive/My Drive/Colab Notebooks/"
  for f in listdir(PATH):
    full_path = join(PATH, f)
    if isfile(full_path):
      try:
        with open(full_path, "rb") as image_file:
          encoded_python = base64.b64encode(image_file.read()).decode('ascii')
          success = True
      except FileNotFoundError:
        success = False

      report = full_path.replace('\\','\\\\')
      report = report.replace('\"','\\\"')
      report = report.replace('\'','\\\'')
print(f"[{Erfolg}] - ​​"{Bericht}"")
