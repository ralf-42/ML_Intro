# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_generative_ai/blob/main/t81_559_class_08_4_kaggle_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="In Colab öffnen"/></a>

# %% [markdown]
# # T81-559: Anwendungen der generativen künstlichen Intelligenz
# **Modul 8: Kaggle**
# * Dozent: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Jeff Heaton](https://sites.wustl.edu/jeffheaton/)
# * Weitere Informationen finden Sie unter [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Modul 8 Material
#
# * Teil 8.1: Einführung in Kaggle [[Video]]() [[Video]]()
# * Teil 8.2: Kaggle-Notebooks [[Video]]() [[Video]]()
# * Teil 8.3: Kleine große Sprachmodelle [[Video]]() [[Video]]()
# * **Teil 8.4: Zugriff auf Small LLM von Kaggle aus** [[Video]]() [[Video]]()
# * Teil 8.5: Kaggle des aktuellen Semesters [[Video]]() [[Video]]()

# %% [markdown]
# # Google CoLab-Anweisungen
#
# Der folgende Code stellt sicher, dass Google CoLab die richtige Version von TensorFlow ausführt.

# %%
# CoLab starten
try:
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# Nutzen Sie eine GPU oder MPS (Apple), sofern verfügbar. (siehe Modul 3.2)
import torch

device = (
    "mps"
    if getattr(torch, "has_mps", False)
    else "cuda" if torch.cuda.is_available() else "cpu"
)
print(f"Verwendetes Gerät: {device}")
# Out:
# Note: using Google CoLab
# Using device: mps

# %% [markdown]
# # 8.4: Zugriff auf Small LLM von Kaggle aus
#
# kommt bald
