# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_deep_learning/blob/main/t81_558_class_13_5_new_tech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="In Colab öffnen"/></a>

# %% [markdown]
# # T81-558: Anwendungen tiefer neuronaler Netzwerke
# **Modul 14: Andere neuronale Netzwerktechniken**
# * Dozent: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Jeff Heaton](https://sites.wustl.edu/jeffheaton/)
# * Weitere Informationen finden Sie unter [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Modul 13 Videomaterial
#
# * Teil 13.1: Verwenden von Denoising Autocodern [[Video]]() [[Video]]()
# * Teil 13.2: Anomalieerkennung [[Video]]() [[Video]]()
# * Teil 13.3: Modelldrift und Neutraining [[Video]]() [[Video]]()
# * Teil 13.4: Tensor Processing Units (TPUs) [[Video]]() [[Video]]()
# * **Teil 13.5: Zukünftige Richtungen in der künstlichen Intelligenz** [[Video]]() [[Video]]()

# %% [markdown]
# # Google CoLab-Anweisungen
#
# Der folgende Code überprüft, ob Google CoLab installiert ist, und richtet die richtigen Hardwareeinstellungen für PyTorch ein.

# %%
import torch

try:
    import google.colab

    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False

# Nutzen Sie eine GPU oder MPS (Apple), sofern verfügbar. (siehe Modul 3.2)
has_mps = torch.backends.mps.is_built()
device = "mps" if has_mps else "gpu" if torch.cuda.is_available() else "cpu"
print(f"Verwendetes Gerät: {device}")

# %% [markdown]
# # Teil 13.5: Zukünftige Richtungen in der künstlichen Intelligenz
#
# Dieser Kurs wird häufig geändert, um mit der sich schnell entwickelnden Deep-Learning-Landschaft Schritt zu halten. Wenn Sie diesen Kurs weiterhin verfolgen möchten, empfehle ich Ihnen, mir auf den folgenden Seiten zu folgen:
#
# * [GitHub](https://github.com/jeffheaton) – Ich poste alle Änderungen auf GitHub.
# * [Jeff Heaton's YouTube Channel](https://www.youtube.com/user/HeatonResearch) – Ich füge meinem Kanal neue Videos für diesen Kurs hinzu.
#
#
# Ich hoffe, dass Ihnen dieser Kurs gefallen hat. Wenn Sie Verbesserungsvorschläge oder Technologievorschläge haben, setzen Sie sich bitte mit mir in Verbindung. Dieser Kurs entwickelt sich ständig weiter und ich lade Sie ein, meinen [YouTube channel](https://www.youtube.com/user/HeatonResearch) zu abonnieren, um meine neuesten Updates zu erhalten. Ich poste auch häufig Videos, die über den Rahmen dieses Kurses hinausgehen, daher ist der Kanal selbst ein guter nächster Schritt. Vielen Dank für Ihr Interesse und Ihre Konzentration auf diesen Kurs. Weitere Social-Media-Links für mich sind:
#
# * [Jeff Heaton GitHub](https://github.com/jeffheaton)
# * [Jeff Heaton Twitter](https://twitter.com/jeffheaton)
# * [Jeff Heaton Medium](https://medium.com/@heatonresearch)
