# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/app_deep_learning/blob/main/t81_558_class_07_5_dream_booth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="In Colab öffnen"/></a>

# %% [markdown]
# # T81-558: Anwendungen tiefer neuronaler Netzwerke
#
# **Modul 7: Bildgenerierende Modelle**
#
# - Dozent: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Jeff Heaton](https://sites.wustl.edu/jeffheaton/)
# – Weitere Informationen finden Sie unter [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Modul 7 Material
#
# - Teil 7.1 Einführung in Generative AI [[Video]](https://www.youtube.com/watch?v=2FbkbSnS8sg&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Video]](https://www.youtube.com/watch?v=2FbkbSnS8sg&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN)
# - Teil 7.2 Gesichter generieren mit StyleGAN3 [[Video]](https://www.youtube.com/watch?v=VcI2o1yEQa0&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Video]](https://www.youtube.com/watch?v=VcI2o1yEQa0&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN)
# - Teil 7.3 GANS zur Verbesserung alter Fotos Deoldify [[Video]](https://www.youtube.com/watch?v=y7HvjfKsZ50&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Video]](https://www.youtube.com/watch?v=y7HvjfKsZ50&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN)
# - Teil 7.4 Text zu Bildern mit StableDiffusion [[Video]](https://www.youtube.com/watch?v=gLj6-gJ-lR4&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Video]](https://www.youtube.com/watch?v=gLj6-gJ-lR4&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN)
# - **Teil 7.5 Feinabstimmung mit Dreambooth** [[Video]](https://www.youtube.com/watch?v=G_FYFSzkB5Y&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Video]](https://www.youtube.com/watch?v=G_FYFSzkB5Y&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN)

# %% [markdown]
# # Google CoLab-Anweisungen
#
# Der folgende Code stellt sicher, dass Google CoLab die richtige Version von TensorFlow ausführt.

# %%
try:
    import google.colab

    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Note: using Google CoLab

# %% [markdown]
# # Teil 7.5 Feinabstimmung mit Dreambooth
#
# Generative Modelle werden häufig feinabgestimmt. In diesem Abschnitt werden wir ein generatives Modell feinabstimmen, um ein zusätzliches Objekt einzuschließen, das dem Modell bekannt ist. Eine Anwendung besteht darin, Ihr eigenes Gesicht in das Modell einzufügen, wodurch Sie als Cartoon oder auf verschiedene Arten gerendert werden können. Abbildung 7.JEFF zeigt mich selbst als Star Trek-Figur gerendert.
#
# **Abbildung 7.JEFF: Jeff als Star Trek-Charakter**
#
# ![Jeff Star Trek](https://data.heatonresearch.com/images/wustl/class/jeff-startrek.jpg)
#
# Der erste Schritt besteht darin, Ihre Daten zu sammeln. Sie sollten zwischen 10 und 20 verschiedene Bilder Ihres Motivs aus unterschiedlichen Winkeln haben.
#
# **Abbildung 7.JEFFS: Mehrere Bilder von Jeff aus verschiedenen Winkeln**
#
# ![Jeff Star Trek](https://data.heatonresearch.com/images/wustl/class/jeffs.jpg)
#
# Um ein Modell zu optimieren, sollten Sie das folgende CoLab-Notizbuch verwenden. Dadurch kann Dream Booth von CoLab aus ausgeführt werden. Dream Booth ist ein Programm, das häufig zum Optimieren stabiler Diffusionsmodelle verwendet wird.
#
# * [Finetuning with Dreambooth](https://colab.research.google.com/github/ShivamShrirao/diffusers/blob/main/examples/dreambooth/DreamBooth_Stable_Diffusion.ipynb)
#
# Es gibt auch kommerzielle Dienste, die Zeit zum Erstellen stabiler Diffusionsmodelle verkaufen. Dies kann im Vergleich zur Anschaffung und Konfiguration eigener Hardware sehr wirtschaftlich sein.
#
# * [Diffusion Hub](https://diffusionhub.firstpromoter.com/)
